# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
print(plt.plot(x, y))
# Out:
# [<matplotlib.lines.Line2D object at 0x000002D452DEBC10>]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
# d:\Coding_2025\chatGPT\.venv\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\Coding_2025\chatGPT\.venv\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\Coding_2025\chatGPT\.venv\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\Coding_2025\chatGPT\.venv\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\Coding_2025\chatGPT\.venv\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\Coding_2025\chatGPT\.venv\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# d:\Coding_2025\chatGPT\.venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Coding_2025\chatGPT\.venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Coding_2025\chatGPT\.venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Coding_2025\chatGPT\.venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Coding_2025\chatGPT\.venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\Coding_2025\chatGPT\.venv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans',
#  'STIXSizeOneSym',
#  'cmr10',
#  'DejaVu Sans',
#  'STIXSizeFiveSym',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'STIXSizeTwoSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'cmtt10',
#  'STIXGeneral',
#  'DejaVu Serif Display',
#  'DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'cmsy10',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'cmmi10',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'cmb10',
#  'STIXSizeThreeSym',
#  'STIXSizeThreeSym',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'cmss10',
#  'cmex10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Display',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'NanumMyeongjo Eco',
#  'NanumSquareRound',
#  'Lucida Bright',
#  'Courier New',
#  'HYGraphic-Medium',
#  'Chiller',
#  'Rockwell Condensed',
#  'HCR Batang ExtB',
#  'Lucida Bright',
#  'HCR Batang ExtB',
#  'Microsoft Himalaya',
#  'NanumGothic Eco',
#  'Book Antiqua',
#  'KoPubDotum Light',
#  'Lucida Fax',
#  'Harlow Solid Italic',
#  'Copperplate Gothic Bold',
#  'Segoe UI',
#  'Forte',
#  'NanumSquare',
#  'Freestyle Script',
#  'SimSun',
#  'NanumSquare Neo Light',
#  'Rockwell Condensed',
#  'Corbel',
#  'Tahoma',
#  'Edwardian Script ITC',
#  'NanumSquare_ac',
#  'Dubai',
#  'Microsoft Tai Le',
#  'Brush Script MT',
#  'Segoe Fluent Icons',
#  'Algerian',
#  'NanumGothic Eco',
#  'Ami R',
#  'Tw Cen MT',
#  'Perpetua',
#  'Bell MT',
#  'Elephant',
#  'Segoe Script',
#  'Franklin Gothic Heavy',
#  'Agency FB',
#  'HYGothic-Medium',
#  'NanumSquare_ac',
#  'Ravie',
#  'Garamond',
#  'Segoe UI',
#  'Nanum GoRyeoGeurGgor',
#  'NanumSquare',
#  'Franklin Gothic Medium',
#  'Century Gothic',
#  'Rockwell',
#  'Wide Latin',
#  'NanumBarunGothic',
#  'Mistral',
#  'NanumBarunGothic',
#  'Pretendard',
#  'Engravers MT',
#  'Segoe UI',
#  'Nanum GarMaesGeur',
#  'Nirmala UI',
#  'NanumGothic',
#  'Ebrima',
#  'Hancom Gothic',
#  'Georgia',
#  'Batang',
#  'Perpetua',
#  'Headline R',
#  'Vivaldi',
#  'Franklin Gothic Medium',
#  'Verdana',
#  'Rockwell',
#  'Segoe Print',
#  'NanumMyeongjo Eco',
#  'Cambria',
#  'Californian FB',
#  'SimSun-ExtG',
#  'Informal Roman',
#  'Berlin Sans FB',
#  'Segoe UI',
#  'MaruBuri',
#  'Berlin Sans FB',
#  'Eras Medium ITC',
#  'Paperlogy',
#  'Yu Gothic',
#  'Bodoni MT',
#  'Nanum GoDigANiGoGoDing',
#  'Palatino Linotype',
#  'Lucida Bright',
#  'Freesentation',
#  'Rockwell',
#  'Tw Cen MT Condensed',
#  'HCR Batang',
#  'Niagara Engraved',
#  'Harrington',
#  'Century Gothic',
#  'NanumSquareRound',
#  'NanumSquareRound',
#  'French Script MT',
#  'Arial',
#  'Arial',
#  'Papyrus',
#  'HYPMokGak-Bold',
#  'Segoe UI',
#  'Lucida Fax',
#  'Perpetua Titling MT',
#  'Tw Cen MT Condensed',
#  'Dubai',
#  'Tw Cen MT',
#  'Constantia',
#  'Century',
#  'Gill Sans MT Condensed',
#  'KoPubWorldDotum',
#  'Leelawadee',
#  'Malgun Gothic',
#  'Bookshelf Symbol 7',
#  'Times New Roman',
#  'Segoe UI',
#  'Yu Gothic',
#  'Haettenschweiler',
#  'Arial Rounded MT Bold',
#  'Pretendard',
#  'Perpetua Titling MT',
#  'Haan Wing2',
#  'Stencil',
#  'Leelawadee UI',
#  'Pretendard Variable',
#  'Goudy Old Style',
#  'Dubai',
#  'Century Gothic',
#  'Paperlogy',
#  'Nanum HyeJunCe',
#  'Trebuchet MS',
#  'NanumMyeongjo',
#  'Goudy Stout',
#  'Microsoft Uighur',
#  'Rage Italic',
#  'Microsoft PhagsPa',
#  'KoPubWorldBatang',
#  'NewJumja',
#  'Freesentation',
#  'NanumBarunpen',
#  'Tahoma',
#  'NanumBarunGothic',
#  'Segoe MDL2 Assets',
#  'Consolas',
#  'OCR A Extended',
#  'Paperlogy',
#  'Gadugi',
#  'Noto Serif KR',
#  'MT Extra',
#  'MaruBuri',
#  'Comic Sans MS',
#  'Segoe UI',
#  'Arial',
#  'Trebuchet MS',
#  'Lucida Sans Typewriter',
#  'Colonna MT',
#  'Freesentation',
#  'Calisto MT',
#  'Calisto MT',
#  'Footlight MT Light',
#  'Nanum GangInHanWiRo',
#  'NanumBarunGothic',
#  'Pretendard',
#  'Gadugi',
#  'Segoe UI Emoji',
#  'Arial',
#  'Microsoft Uighur',
#  'NanumMyeongjo Eco',
#  'Microsoft New Tai Lue',
#  'Lucida Sans',
#  'HCR Batang',
#  'Myanmar Text',
#  'HancomEQN',
#  'NEXON Football Gothic B',
#  'Bodoni MT',
#  'Verdana',
#  'Bodoni MT',
#  'Symbol',
#  'Perpetua',
#  'Lucida Sans Unicode',
#  'Pyunji R',
#  'Webdings',
#  'Bookman Old Style',
#  'MaruBuri',
#  'Candara',
#  'NanumSquare',
#  'NEXON Football Gothic B',
#  'Bookman Old Style',
#  'HYGungSo-Bold',
#  'Lucida Sans',
#  'HYGothic-Extra',
#  'Ebrima',
#  'NanumSquare Neo Heavy',
#  'Lucida Sans Typewriter',
#  'Gill Sans MT',
#  'Pretendard',
#  'NanumGothic',
#  'Eras Bold ITC',
#  'Snap ITC',
#  'Century Gothic',
#  'Calisto MT',
#  'Malgun Gothic',
#  'Sitka',
#  'Corbel',
#  'SimSun-ExtB',
#  'Gill Sans MT',
#  'HYSinMyeongJo-Medium',
#  'Imprint MT Shadow',
#  'Pretendard',
#  'Paperlogy',
#  'Bahnschrift',
#  'Bauhaus 93',
#  'Book Antiqua',
#  'High Tower Text',
#  'NanumBarunGothic YetHangul',
#  'Cambria',
#  'Candara',
#  'MV Boli',
#  'MS Gothic',
#  'Rockwell Extra Bold',
#  'Script MT Bold',
#  'Courier New',
#  'HyhwpEQ',
#  'MS Outlook',
#  'Bodoni MT',
#  'Bookman Old Style',
#  'NanumGothic',
#  'Han Santteut Dotum',
#  'Consolas',
#  'Consolas',
#  'Matura MT Script Capitals',
#  'NanumMyeongjo YetHangul',
#  'Lucida Fax',
#  'Bookman Old Style',
#  'NanumSquare Neo ExtraBold',
#  'HoloLens MDL2 Assets',
#  'Bodoni MT',
#  'Freesentation',
#  'Vladimir Script',
#  'Bernard MT Condensed',
#  'Parchment',
#  'Eras Light ITC',
#  'Comic Sans MS',
#  'Poor Richard',
#  'Corbel',
#  'Franklin Gothic Book',
#  'Franklin Gothic Demi',
#  'Impact',
#  'Wingdings 2',
#  'Segoe UI',
#  'Constantia',
#  'HYShortSamul-Medium',
#  'Book Antiqua',
#  'Paperlogy',
#  'Yu Gothic',
#  'Arial',
#  'Georgia',
#  'Bodoni MT',
#  'Verdana',
#  'Tw Cen MT Condensed Extra Bold',
#  'Calibri',
#  'KoPubWorldBatang',
#  'Courier New',
#  'Bodoni MT',
#  'Franklin Gothic Heavy',
#  'MoeumT R',
#  'Segoe Print',
#  'NanumSquare_ac',
#  'Sylfaen',
#  'Freesentation',
#  'Lucida Bright',
#  'Segoe UI',
#  'NanumGothic',
#  'Paperlogy',
#  'Tw Cen MT',
#  'Californian FB',
#  'Pretendard',
#  'NanumSquare Neo Bold',
#  'Consolas',
#  'Microsoft New Tai Lue',
#  'NanumMyeongjo',
#  'NanumSquare_ac',
#  'NEXON Football Gothic L',
#  'Franklin Gothic Demi',
#  'Noto Sans KR',
#  'Nirmala UI',
#  'Trebuchet MS',
#  'Old English Text MT',
#  'Microsoft JhengHei',
#  'NanumSquare',
#  'Niagara Solid',
#  'Arial',
#  'Franklin Gothic Book',
#  'Verdana',
#  'NanumSquareRound',
#  'Viner Hand ITC',
#  'Cooper Black',
#  'Courier New',
#  'Wingdings',
#  'Lucida Sans Typewriter',
#  'Comic Sans MS',
#  'Monotype Corsiva',
#  'Nanum GangBuJangNimCe',
#  'Elephant',
#  'Segoe UI',
#  'Blackadder ITC',
#  'Bell MT',
#  'Times New Roman',
#  'Calibri',
#  'KoPubDotum Medium',
#  'Microsoft JhengHei',
#  'Pretendard',
#  'Sitka',
#  'Castellar',
#  'Candara',
#  'Eras Demi ITC',
#  'Calisto MT',
#  'Segoe UI Symbol',
#  'Arial',
#  'Paperlogy',
#  'Curlz MT',
#  'Juice ITC',
#  'Microsoft Yi Baiti',
#  'Ink Free',
#  'Copperplate Gothic Light',
#  'Onyx',
#  'Palatino Linotype',
#  'Pretendard',
#  'NanumMyeongjo',
#  'HCR Dotum',
#  'Nanum GomSinCe',
#  'Mongolian Baiti',
#  'Freesentation',
#  'Garamond',
#  'Calibri',
#  'Lucida Console',
#  'Candara',
#  'Book Antiqua',
#  'HCR Dotum Ext',
#  'New Gulim',
#  'Century Schoolbook',
#  'Hancom Gothic',
#  'Calibri',
#  'Trebuchet MS',
#  'Rockwell',
#  'Century Schoolbook',
#  'Freesentation',
#  'Showcard Gothic',
#  'Gill Sans MT',
#  'Pretendard',
#  'NanumGothic Eco',
#  'Malgun Gothic',
#  'Arial',
#  'Palace Script MT',
#  'Berlin Sans FB Demi',
#  'Franklin Gothic Medium Cond',
#  'HCR Batang Ext',
#  'Comic Sans MS',
#  'Felix Titling',
#  'Segoe UI Historic',
#  'Sans Serif Collection',
#  'Times New Roman',
#  'Segoe UI',
#  'MingLiU-ExtB',
#  'KoPubWorldDotum',
#  'Goudy Old Style',
#  'Candara',
#  'Lucida Calligraphy',
#  'Candara',
#  'Magneto',
#  'Bodoni MT',
#  'Corbel',
#  'Microsoft PhagsPa',
#  'Calibri',
#  'Dubai',
#  'Yu Gothic',
#  'Playbill',
#  'Broadway',
#  'Gill Sans MT',
#  'Jokerman',
#  'Maiandra GD',
#  'Palatino Linotype',
#  'Paperlogy',
#  'Gulim',
#  'Lucida Sans',
#  'HYPost-Medium',
#  'Paperlogy',
#  'Bodoni MT',
#  'Times New Roman',
#  'Bradley Hand ITC',
#  'Gill Sans Ultra Bold',
#  'Cambria',
#  'Leelawadee',
#  'Bodoni MT',
#  'Nanum Pen Script',
#  'HYMyeongJo-Extra',
#  'Myanmar Text',
#  'MaruBuri',
#  'NanumSquare Neo Regular',
#  'NanumBarunpen',
#  'Freesentation',
#  'Corbel',
#  'Gill Sans MT Ext Condensed Bold',
#  'Modern No. 20',
#  'Constantia',
#  'Leelawadee UI',
#  'Baskerville Old Face',
#  'Segoe UI',
#  'Gloucester MT Extra Condensed',
#  'Lucida Sans',
#  'MS Reference Specialty',
#  'Wingdings 3',
#  'Franklin Gothic Demi Cond',
#  'Corbel',
#  'Microsoft YaHei',
#  'Lucida Fax',
#  'Bell MT',
#  'Javanese Text',
#  'Segoe UI Variable',
#  'Georgia',
#  'Agency FB',
#  'Lucida Sans Typewriter',
#  'Nanum GaRamYeonGgoc',
#  'Britannic Bold',
#  'KoPubDotum Bold',
#  'Gabriola',
#  'Calibri',
#  'HYPost-Light',
#  'Microsoft Tai Le',
#  'MS Reference Sans Serif',
#  'Perpetua',
#  'Magic R',
#  'Microsoft Sans Serif',
#  'Gigi',
#  'HYHeadLine-Medium',
#  'Leelawadee UI',
#  'Centaur',
#  'Tempus Sans ITC',
#  'Gill Sans Ultra Bold Condensed',
#  'Tw Cen MT',
#  'Yet R',
#  'HCR Dotum',
#  'Constantia',
#  'Goudy Old Style',
#  'KoPubWorldBatang',
#  'Freesentation',
#  'MaruBuri',
#  'Han Santteut Dotum',
#  'Georgia',
#  'Century Schoolbook',
#  'Kunstler Script',
#  'Microsoft JhengHei',
#  'KoPubWorldDotum',
#  'Californian FB',
#  'Lucida Handwriting',
#  'Cambria',
#  'Kristen ITC',
#  'Garamond',
#  'Nanum Brush Script',
#  'Arial',
#  'Segoe Script',
#  'Pristina',
#  'Nirmala UI',
#  'Microsoft YaHei',
#  'Century Schoolbook',
#  'Palatino Linotype',
#  'Bodoni MT',
#  'Microsoft YaHei',
#  'High Tower Text']

# %%
plt.plot(x, y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1, 2])
