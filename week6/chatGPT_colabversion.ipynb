# %% [markdown]
# ### openAI API를 사용할 라이브러리 설치

# %%
# !pip install --upgrade pip
# !pip install openAI
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.2-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 13.5 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.2
# Requirement already satisfied: openAI in /usr/local/lib/python3.12/dist-packages (1.109.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openAI) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openAI) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openAI) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openAI) (0.11.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openAI) (2.11.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openAI) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openAI) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openAI) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openAI) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openAI) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openAI) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openAI) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openAI) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openAI) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openAI) (0.4.2)

# %% [markdown]
# ### 간단한 채팅 (chat01)

# %%
# Colab Secrets Manager에서 API 키 불러오기
from google.colab import userdata
from openai import OpenAI

# Secrets Manager에 저장한 API 키 이름 (예: OPENAI_API_KEY)
# Secrets Manager에 저장할 때 사용한 이름과 동일해야 합니다.
openai_api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=openai_api_key)

response = client.responses.create(
    model="gpt-5",
    input=[
        {
            "role": "user",
            "content": "너는 누구야?"
        }
    ]
)

print(response.output_text)
# Out:
# 저는 OpenAI가 만든 인공지능 어시스턴트 ChatGPT예요. 질문에 답하고, 글쓰기·요약·번역·코딩을 돕거나 이미지 내용을 분석하는 등 다양한 작업을 도와드릴 수 있어요. 가끔 틀릴 수도 있으니 중요한 내용은 확인해 주세요. 무엇을 도와드릴까요?

# %% [markdown]
# ### 간단한 채팅 + 옵션 (chat02)

# %%
from google.colab import userdata
from openai import OpenAI

openai_api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=openai_api_key)

response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        {
            "role": "user",
            "content": "코딩을 배워야 하는 이유를 2문장으로 설명해줘"
        }
    ],
    temperature=1.5,  # 0~2, 높을수록 창의적
    max_output_tokens=20    # 출력 토큰 수 제한
)

print(response.output_text)
# Out:
# 코딩을 배우면 문제 해결 능력과 논리적 사고를 키울 수 있어 다양한

# %% [markdown]
# ### 역할 (role, system, assistant, user)

# %%
from google.colab import userdata
from openai import OpenAI

openai_api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=openai_api_key)

# Role: 역할
# system - 음악을 좋아하는 사람, 음식을 잘하는 사람, 코딩 전문가, 조언 전문가, ...
# assistant - 챗봇
# user - 사용자

response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        {
            "role": "user",
            "content": "보안 전문가"
        }
    ]
)

print(response.output_text)
# Out:
# 보안 전문가란 정보 보안, 네트워크 보안, 시스템 보안 등을 전문적으로 다루는 전문 인력을 의미합니다. 이들은 기업이나 기관의 데이터를 보호하고, 사이버 공격으로부터 시스템을 방어하기 위해 다양한 기술과 방법을 사용합니다.
#
# 주요 역할은 다음과 같습니다:
#
# 1. **위험 분석 및 평가**: 잠재적인 보안 위협을 식별하고 이를 평가합니다.
# 2. **보안 정책 개발**: 조직의 보안 규칙과 절차를 설계하고 문서화합니다.
# 3. **침해 사고 대응**: 보안 사고 발생 시 신속하게 대응하고, 사고를 분석하여 재발 방지를 위한 개선책을 마련합니다.
# 4. **보안 시스템 구축**: 방화벽, 침입 탐지 시스템(IDS), 암호화 솔루션 등을 구축하고 유지 관리합니다.
# 5. **보안 감사 및 테스트**: 시스템의 보안 상태를 점검하고, 침투 테스트 등을 통해 취약점을 찾아냅니다.
# 6. **사용자 교육**: 직원들에게 보안 인식 교육을 실시하여 보안 사고를 예방합니다.
#
# 또한, 특정 분야에 따라 IT 보안, 물리적 보안, 클라우드 보안 등 다양한 전문 분야로 나누어질 수 있습니다. 보안 전문가는 다양한 자격증(예: CISSP, CISM, CEH 등)을 보유하고 있을 수 있으며, 최신 보안 동향을 파악하고 지속적인 교육을 받는 것이 중요합니다.

# %%
from google.colab import userdata
from openai import OpenAI

openai_api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=openai_api_key)

# Role: 역할
# system - 음악을 좋아하는 사람, 음식을 잘하는 사람, 코딩 전문가, 조언 전문가, ...
# assistant - 챗봇
# user - 사용자

response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        {
            "role": "system",
            "content": "당신은 프로그래밍 전문가입니다. 사용자가 입력한 분야에 필요한 기술과 학습 방법을 3문장 이내로 알려주세요."
        },
        {
            "role": "user",
            "content": "보안 전문가"
        }
    ]
)

print(response.output_text)
# Out:
# 보안 전문가가 되기 위해서는 네트워크 보안, 시스템 보안, 암호화, 해킹 기법 등을 깊이 있게 이해해야 합니다. 이론 학습과 함께 CTF(Capture The Flag) 대회나 관련 프로젝트에 참여하여 실무 경험을 쌓는 것이 중요합니다. 또한, CISSP, CEH 등 관련 자격증 취득을 통해 전문성을 강화하는 것도 고려해보세요.

# %%
from google.colab import userdata
from openai import OpenAI

openai_api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=openai_api_key)

# Role: 역할
# system - 음악을 좋아하는 사람, 음식을 잘하는 사람, 코딩 전문가, 조언 전문가, ...
# assistant - 챗봇
# user - 사용자

response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        {
            "role": "system",
            "content": "당신은 프로그래밍 학습 조언가입니다."
        },
        {
            "role": "user",
            "content": "초보자가 배우기 좋은 언어를 하나 추천해줘. 이름만 알려줘."
        },
        {
            "role": "assistant",
            "content": "파이썬(Python)"
        },
        {
            "role": "user",
            "content": "어떤 분야에 활용할 수 있어? 간단히 설명해줘."
        }
    ]
)

print(response.output_text)
# Out:
# 파이썬은 다양한 분야에서 활용될 수 있습니다:
#
# 1. **웹 개발**: Django, Flask 같은 프레임워크를 사용하여 웹 애플리케이션 개발.
# 2. **데이터 과학**: 데이터 분석, 시각화, 머신러닝에 많이 사용됨 (예: Pandas, NumPy, Scikit-learn).
# 3. **자동화**: 반복적인 작업을 자동화하는 스크립트 작성.
# 4. **게임 개발**: Pygame과 같은 라이브러리로 간단한 게임 개발.
# 5. **소프트웨어 개발**: 다양한 애플리케이션 및 도구 개발에 널리 사용됨.
#
# 이처럼 파이썬은 범용성 덕분에 여러 분야에서 유용하게 쓰입니다.

# %% [markdown]
# ### 제로샷/원샷/퓨샷

# %%
from google.colab import userdata
from openai import OpenAI

openai_api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=openai_api_key)

response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        {
            "role": "system",
            "content": "뉴스 제목을 보고 어떤 카테고리에 속하는지 알려줘."
        },
        {
            "role": "user",
            "content": "새로운 블랙홀 발견, 우주 연구에 새로운 가능성"
        }
    ]
)

print(response.output_text)
# Out:
# 이 뉴스 제목은 "우주" 또는 "과학" 카테고리에 속합니다. 블랙홀 발견은 천문학적 연구와 관련된 내용이므로 우주 연구에 대한 관심을 반영합니다.

# %%
from google.colab import userdata
from openai import OpenAI

openai_api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=openai_api_key)

response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        {
            "role": "system",
            "content": "뉴스 제목을 보고 어떤 카테고리에 속하는지 알려줘."
        },
        {
            "role": "user",
            "content": "챔피언스 리그, 치열한 순위 다툼"
        },
        {
            "role": "assistant",
            "content": "스포츠"
        },
        {
            "role": "user",
            "content": "새로운 블랙홀 발견, 우주 연구에 새로운 가능성"
        }
    ]
)

print(response.output_text)
# Out:
# 과학 / 우주 탐사

# %%
from google.colab import userdata
from openai import OpenAI

openai_api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=openai_api_key)

response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        {
            "role": "system",
            "content": "뉴스 제목을 보고 어떤 카테고리에 속하는지 알려줘."
        },
        {
            "role": "user",
            "content": "챔피언스 리그, 치열한 순위 다툼"
        },
        {
            "role": "assistant",
            "content": "스포츠"
        },
        {
            "role": "user",
            "content": "자율주행 자동차, 내년부터 상용화 추진"
        },
        {
            "role": "assistant",
            "content": "기술"
        },
        {
            "role": "user",
            "content": "새로운 블랙홀 발견, 우주 연구에 새로운 가능성"
        }
    ]
)

print(response.output_text)
# Out:
# 과학/우주 탐사

# %% [markdown]
# ### 멀티턴

# %%
from google.colab import userdata
from openai import OpenAI

openai_api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=openai_api_key)

while True:
    user_input = input("사용자 입력: ")
    if user_input.lower() in ["quit", "exit", "bye"]:
        print("챗봇을 종료합니다.")
        break

    response = client.responses.create(
        model="gpt-4o-mini",
        input=[
            {
                "role": "user",
                "content": user_input
            }
        ]
    )

    result = response.output_text
    print("챗봇:", result)
# Out:
# 사용자 입력: 안녕
# 챗봇: 안녕하세요! 어떻게 도와드릴까요?
# 사용자 입력: 취미로 자전거를 배우고 싶어
# 챗봇: 자전거를 배우는 것은 정말 즐거운 취미입니다! 처음 시작할 때 고려해야 할 몇 가지 팁을 소개할게요.
#
# 1. **자전거 선택하기**: 초보자에게는 편안하고 안정적인 자전거가 중요합니다. 하이브리드 자전거나 산악자전거를 고려해 보세요.
#
# 2. **안전 장비 착용**: 헬멧, 무릎 보호대, 팔꿈치 보호대 등을 착용해 안전을 지키세요.
#
# 3. **기본 기술 익히기**: 자전거를 타는 기본적인 기술(균형 잡기, braking, 회전 등)을 연습하세요.
#
# 4. **조용한 장소에서 연습**: 사람이나 차량이 적은 안전한 장소에서 연습하는 것이 좋습니다.
#
# 5. **점진적으로 거리 늘리기**: 처음에는 짧은 거리부터 시작하고 점차 거리를 늘려가세요.
#
# 6. **자전거 유지 관리**: 자전거의 상태를 수시로 점검하고 유지보수하는 것이 중요합니다.
#
# 7. **커뮤니티 참여하기**: 자전거 동호회나 그룹 라이딩에 참여하면 더 재미있고, 많은 조언을 얻을 수 있습니다.
#
# 즐거운 자전거 타기 되길 바랍니다!
# 사용자 입력: 꼭 필요한 장비는 무엇이 있을까?
# 챗봇: 필요한 장비는 사용 목적에 따라 다르지만, 일반적으로 다음과 같은 주요 장비들이 많이 필요합니다:
#
# 1. **컴퓨터/노트북**: 작업, 연구, 인터넷 연결 등 기본적인 작업을 위한 필수 장비입니다.
# 2. **스마트폰**: 소통, 정보 검색, 일정 관리 등을 용이하게 도와줍니다.
# 3. **프린터/복합기**: 문서 출력이나 복사, 스캔이 필요할 때 유용합니다.
# 4. **인터넷 모뎀/라우터**: 안정적인 인터넷 연결을 위해 필수적입니다.
# 5. **정리 도구**: 서류정리함, 파일 폴더, 바인더 등으로 공간을 효율적으로 사용할 수 있습니다.
# 6. **사무용 가구**: 책상, 의자 등 작업 공간을 편안하게 유지하는 데 중요합니다.
# 7. **필기 도구**: 노트, 펜, 마커 등은 아이디어를 기록하거나 계획을 세우는 데 필요합니다.
# 8. **카메라**: 사진이나 동영상 촬영이 필요할 때 유용합니다.
#
# 구체적인 필요 장비는 여러분의 목표와 환경에 따라 달라질 수 있습니다. 어떤 작업이나 활동을 염두에 두고 계신가요? 더 구체적으로 말씀해 주시면, 보다 적절한 장비를 추천해 드릴 수 있습니다.
# 사용자 입력: quit
# 챗봇을 종료합니다.

# %%
from google.colab import userdata
from openai import OpenAI

openai_api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=openai_api_key)

messages = [
    {"role": "system", "content": "You are a helpful assistant."}
]

while True:
    user_input = input("사용자 입력: ")
    if user_input.lower() in ["quit", "exit", "bye"]:
        print("챗봇을 종료합니다.")
        break

    messages.append(
        {"role": "user", "content": user_input}
    )

    response = client.responses.create(
        model="gpt-4o-mini",
        input=messages
    )

    result = response.output_text
    print("챗봇:", result)

    messages.append(
        {"role": "assistant", "content": result}
    )
# Out:
# 사용자 입력: 안녕
# 챗봇: 안녕하세요! 어떻게 도와드릴까요?
# 사용자 입력: 취미로 자전거를 배우고 싶어
# 챗봇: 자전거를 배우는 것은 정말 좋은 취미입니다! 시작하기 전에 몇 가지 팁을 드릴게요.
#
# 1. **안전 장비 착용**: 헬멧, 무릎 보호대, 팔꿈치 보호대 등을 착용하세요. 안전이 가장 중요합니다.
#
# 2. **적절한 자전거 선택**: 본인의 키와 체형에 맞는 자전거를 선택하세요. 처음에는 산악 자전거나 하이브리드 자전거가 좋습니다.
#
# 3. **기본 기술 연습**: 자전거를 타는 기본인 균형 잡기, 브레이크 사용, 기어 조작 등을 연습하세요.
#
# 4. **넓은 공간에서 연습**: 사람들 없이 넓은 공간에서 자전거를 타는 연습을 해보세요.
#
# 5. **조금씩 거리 늘리기**: 처음에는 짧은 거리부터 시작해서 점차 거리를 늘려가세요.
#
# 6. **주변 도로 확인**: 안전한 도로에서 타는 것도 중요합니다. 자전거 전용 도로가 있는지 확인해보세요.
#
# 7. **함께 타기**: 친구나 가족과 함께 자전거를 타면 더 즐겁고 안전하게 배울 수 있습니다.
#
# 궁금한 점이나 더 필요한 정보가 있으면 언제든지 물어보세요!
# 사용자 입력: 꼭 필요한 장비는 무엇이 있을까?
# 챗봇: 자전거를 배우기 위해 꼭 필요한 장비는 다음과 같습니다:
#
# 1. **헬멧**: 머리를 보호하기 위한 필수 장비입니다. 안전을 위해 반드시 착용하세요.
#
# 2. **자전거**: 본인에게 맞는 크기와 유형의 자전거를 선택하세요. 처음에는 하이브리드 자전거나 산악 자전거가 좋습니다.
#
# 3. **장갑**: 손의 편안함과 그립을 높여주며, 낙상 시 손을 보호해 줍니다.
#
# 4. **무릎 및 팔꿈치 보호대**: 추가적인 보호 장비로, 특히 초보자에게 유용합니다.
#
# 5. **편안한 옷**: 자전거를 타기 편한 운동복이나 기능성 의류를 착용하는 것이 좋습니다.
#
# 6. **물병 및 물통 홀더**: 수분 보충을 위해 자전거에 물병을 장착할 수 있는 홀더도 유용합니다.
#
# 7. **기본 도구**: 펑크 난 경우를 대비해 펌프와 자전거 도구 세트를 갖추는 것이 좋습니다.
#
# 8. **안전 장치**: 자전거를 도난당하지 않도록 자물쇠를 준비하세요.
#
# 초보자는 안전과 편안함이 가장 중요하니, 필요한 장비를 잘 구비하고 시작하세요! 추가적으로 필요한 것이 있다면 언제든 물어보세요.
# 사용자 입력: quit
# 챗봇을 종료합니다.

# %% [markdown]
# ### 퀴즈: 별자리 챗봇
#
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import userdata
from openai import OpenAI

openai_api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=openai_api_key)

user_input = input("생일을 입력하세요: ")

response = client.responses.create(
    model="gpt-4o-mini",
    input=[
        {
            "role": "user",
            "content": f"사용자가 입력한 생일 {user_input}에 해당하는 별자리를 알려주고, 그 별자리 사람들의 특징과 성격을 3문장 이내로 알려줘."
        }
    ]
)

print("챗봇: ", response.output_text)
print("ChatGPT 응답 완료")
# Out:
# 생일을 입력하세요: 7월 17일
# 챗봇:  7월 17일에 해당하는 별자리는 게자리(Cancer)입니다. 게자리 사람들은 감정적으로 깊이 연결되고, 가족과 친구를 소중히 여기는 성향이 강합니다. 이들은 보살피는 마음이 크고, 타인의 감정에 민감하지만, 때로는 외부 세계에 대하여 수줍음이 많을 수 있습니다.

# %%
from google.colab import userdata
from openai import OpenAI

openai_api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=openai_api_key)

messages = [
    {"role": "system", "content": "당신은 별자리 전문가입니다. 사용자가 생일을 입력하면 해당 별자리와 그 성격 및 특징을 3문장 이내로 설명해 주세요."}
]

while True:
    user_input = input("생일을 입력하세요: ")
    if user_input.lower() in ["quit", "exit", "bye"]:
        print("챗봇을 종료합니다.")
        break

    messages.append(
        {"role": "user", "content": user_input}
    )

    response = client.responses.create(
        model="gpt-4o-mini",
        input=messages
    )

    result = response.output_text
    print("챗봇:", result)
    print("ChatGPT 응답 완료")

    break

    messages.append(
        {"role": "assistant", "content": result}
    )
# Out:
# 생일을 입력하세요: 7월 17일
# 챗봇: 7월 17일에 태어난 사람은 암컷자리(Cancer)입니다. 이들은 감정적으로 민감하고, 가족과 친구를 중요시하며, 돌봄과 지지를 아끼지 않는 성격을 가지고 있습니다. 또한 창의적이고 직관력이 뛰어나며, 때로는 내성적인 면모를 보이기도 합니다.
# ChatGPT 응답 완료

# %% [markdown]
# ### 프로젝트
# ![image.png](data:image/png;base64,...)

# %%
import json

from google.colab import userdata
from openai import OpenAI

openai_api_key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=openai_api_key)


def generate_mbti_question():
    prompt = """
다음 지시에 따라 반드시 JSON만 출력해.
MBTI 성격 유형을 판별할 수 있는 객관식 질문 4개를 JSON 형식으로 만들어줘.
각 질문은 다음 MBTI 요소를 순서대로 판별해야 해.
1. 외향형(E) vs 내향형(I)
2. 감각형(S) vs 직관형(N)
3. 사고형(T) vs 감정형(F)
4. 판단형(J) vs 인식형(P)

출력은 아래 예시와 같은 JSON 객체만 출력할 것.
설명이나 추가 텍스트는 절대 넣지 마.

{
    "questions": [
        {
            "question": "새로운 사람을 만났을 때 나는?",
            "options": {
                "a": "먼저 말을 걸고 대화를 주도한다.",
                "b": "상대가 말을 걸어오면 대화한다."
            },
            "types": {
                "a": "E",
                "b": "I"
            }
        }
    ]
}
"""

# 질문지
# a) 첫번째 보기 = E
# b) 두번째 보기 = I

    response = client.responses.create(
        model="gpt-4o-mini",
        input=[
            {
                "role": "user",
                "content": prompt
            }
        ]
    )

    return response.output_text

def take_mbti_test(questions):
    questions = json.loads(questions)
    # print(questions)
    mbti = ""

    for item in questions["questions"]:
        print(f"질문: {item['question']}")
        print(f"a) {item['options']['a']}")
        print(f"b) {item['options']['b']}")
        print()
        answer = input("답변을 선택하세요 (a 또는 b): ").strip().lower()
        while answer not in ['a', 'b']:
            answer = input("답변을 선택하세요 (a 또는 b): ").strip().lower()
        if answer in item["types"]:
            mbti += item["types"][answer]

        print()
        print("-" * 40)

    return mbti

def mbti_analysis(mbti_type):
    response = client.responses.create(
        model="gpt-4o-mini",
        input=[
            {
                "role": "user",
                "content": f"MBTI 유형 {mbti_type}의 성격 유형의 특징을 3문장 이내로 간단히 설명해줘."
            }
        ]
    )

    return response.output_text

print("=== 초간단 MBTI 테스트 ===\n")

# MBTI 질문지 생성
questions = generate_mbti_question()
# print("생성된 질문지:", questions)

# 사용자가 질문지를 직접 풀이
mbti_type = take_mbti_test(questions)
print(f"당신의 MBTI 유형은 {mbti_type}입니다!")

# 성격 유형 분석
result = mbti_analysis(mbti_type)
print(result)
print("\n=== 테스트가 종료되었습니다 ===")
# Out:
# === 초간단 MBTI 테스트 ===
#
# 질문: 새로운 사람을 만났을 때 나는?
# a) 먼저 말을 걸고 대화를 주도한다.
# b) 상대가 말을 걸어오면 대화한다.
#
# 답변을 선택하세요 (a 또는 b): a
#
# ----------------------------------------
# 질문: 정보를 받을 때 나는 보통?
# a) 구체적인 사실에 집중한다.
# b) big picture와 가능성에 집중한다.
#
# 답변을 선택하세요 (a 또는 b): b
#
# ----------------------------------------
# 질문: 결정을 내릴 때 나는 주로?
# a) 논리와 규칙에 따른다.
# b) 타인의 감정을 고려한다.
#
# 답변을 선택하세요 (a 또는 b): b
#
# ----------------------------------------
# 질문: 일정을 계획할 때 나는?
# a) 미리 정해둔 대로 진행한다.
# b) 상황에 따라 유연하게 대처한다.
#
# 답변을 선택하세요 (a 또는 b): b
#
# ----------------------------------------
# 당신의 MBTI 유형은 ENFP입니다!
# ENFP는 외향적이고 직관적인 성격으로, 창의적이며 열정적입니다. 사람들과의 관계를 중시하며, 다양한 아이디어와 가능성에 대해 탐구하는 것을 좋아합니다. 또한, 변화를 즐기고 새로운 경험을 추구하는 모험가적인 면모를 가지고 있습니다.
#
# === 테스트가 종료되었습니다 ===
